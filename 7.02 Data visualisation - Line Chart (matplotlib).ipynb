# %% [markdown]
# ### Import Library

# %%
import pandas as pd                               
import matplotlib.pyplot as plt

# %% [markdown]
# ### Prepare Data

# %%
test_features = pd.read_csv('test_features.csv')
test_features = test_features[['Age','Fare']]
test_features.head(10)
# Out:
#          Age     Fare
# 0  29.699118  15.2458
# 1  31.000000  10.5000
# 2  20.000000   7.9250
# 3   6.000000  33.0000
# 4  14.000000  11.2417
# 5  26.000000  78.8500
# 6  29.699118   7.7500
# 7  16.000000  18.0000
# 8  16.000000   7.7500
# 9  19.000000  26.2833

# %% [markdown]
# ### Plot Line Chart

# %%
plt.rc('font',family = 'Times New Roman',  size=22)
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(range(len(test_features)), test_features['Age'],color=(255/255,128/255,128/255),linewidth=1,linestyle="--" ,zorder=0)
ax1.set_ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')
